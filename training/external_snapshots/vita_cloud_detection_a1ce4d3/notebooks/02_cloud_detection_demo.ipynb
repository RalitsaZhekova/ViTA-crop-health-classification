# %% [markdown]
# # Cloud Detection Demo

# %%
# !pip -q install -e "..[model]"
from cloud_detection.pipeline import CloudDetectionPipeline
pipeline=CloudDetectionPipeline.from_yaml('../configs/cloud_detector.yaml')

# %%
result=pipeline.predict_file('../data/raw/cloud_scene_01.tif','../outputs')
result.metadata()

# %%
from PIL import Image
display(Image.open(result.output_files['preview']))
