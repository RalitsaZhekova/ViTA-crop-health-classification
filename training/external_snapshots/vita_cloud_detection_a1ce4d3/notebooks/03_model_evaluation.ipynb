# %% [markdown]
# # Evaluation against a reference mask

# %%
import rasterio
from cloud_detection.metrics import binary_metrics
with rasterio.open('../outputs/cloud_masks/scene_unusable.tif') as ds: pred=ds.read(1)
with rasterio.open('../data/reference_masks/scene_reference.tif') as ds: ref=ds.read(1)
binary_metrics(pred==1,ref==1)
